# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\HP\Documents\All Udemy Practice Codes(Data Science)\datasets\obesity_levels.csv")

# %%
df
# Out:
#         Height      Weight  family_history_with_overweight  SCC  \
# 0     1.620000   64.000000                               1    0
# 1     1.520000   56.000000                               1    1
# 2     1.800000   77.000000                               1    0
# 3     1.800000   87.000000                               0    0
# 4     1.780000   89.800000                               0    0
# ...        ...         ...                             ...  ...
# 2081  1.710730  131.408528                               1    0
# 2082  1.748584  133.742943                               1    0
# 2083  1.752206  133.689352                               1    0
# 2084  1.739450  133.346641                               1    0
# 2085  1.738836  133.472641                               1    0
#
#       MTRANS_Walking    FAVC_z  FCVC_minmax     NCP_z  CAEC_minmax  \
# 0                  0  2.766876          0.5  0.404704     0.333333
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2086 entries, 0 to 2085
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Height                          2086 non-null   float64
#  1   Weight                          2086 non-null   float64
#  2   family_history_with_overweight  2086 non-null   int64
#  3   SCC                             2086 non-null   int64
#  4   MTRANS_Walking                  2086 non-null   int64
#  5   FAVC_z                          2086 non-null   float64
#  6   FCVC_minmax                     2086 non-null   float64
#  7   NCP_z                           2086 non-null   float64
#  8   CAEC_minmax                     2086 non-null   float64
#  9   CH2O_minmax                     2086 non-null   float64
#  10  FAF_minmax                      2086 non-null   float64
#  11  TUE_z                           2086 non-null   float64
# ...

# %%
df.describe()
# Out:
#             Height       Weight  family_history_with_overweight          SCC  \
# count  2086.000000  2086.000000                     2086.000000  2086.000000
# mean      1.702045    86.622985                        0.817354     0.045062
# std       0.093419    26.256245                        0.386469     0.207491
# min       1.450000    39.000000                        0.000000     0.000000
# 25%       1.630000    65.130595                        1.000000     0.000000
# 50%       1.701383    83.000000                        1.000000     0.000000
# 75%       1.768770   108.009452                        1.000000     0.000000
# max       1.980000   165.057269                        1.000000     1.000000
#
#        MTRANS_Walking       FAVC_z  FCVC_minmax        NCP_z  CAEC_minmax  \
# count     2086.000000  2086.000000  2086.000000  2086.000000  2086.000000
# mean         0.026366     0.639326     0.709818     0.763670     0.379834
# ...

# %%
X = df.drop("NObeyesdad",axis=1)
y = df["NObeyesdad"]

# %%
print(y.value_counts(normalize=True))
# Out:
# NObeyesdad
# 4    0.163950
# 6    0.154842
# 5    0.142378
# 2    0.138543
# 1    0.136625
# 3    0.133269
# 0    0.130393
# Name: proportion, dtype: float64

# %%
corr=df.corr()
corr
# Out:
#                                   Height    Weight  \
# Height                          1.000000  0.461701
# Weight                          0.461701  1.000000
# family_history_with_overweight  0.251567  0.500309
# SCC                            -0.135810 -0.201567
# MTRANS_Walking                  0.034303 -0.102000
# FAVC_z                         -0.181310 -0.273515
# FCVC_minmax                    -0.040028  0.216228
# NCP_z                          -0.193668 -0.317271
# CAEC_minmax                    -0.051355 -0.292327
# CH2O_minmax                     0.217372  0.203345
# FAF_minmax                      0.292630 -0.054236
# TUE_z                          -0.077493 -0.274363
# CALC_z                         -0.071933 -0.233389
# Age_bin_minmax                  0.037007  0.338565
# NObeyesdad                      0.134491  0.914836
#
#                                 family_history_with_overweight       SCC  \
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
X.hist(figsize=(15, 10), bins=30,color='skyblue', edgecolor='black')
plt.tight_layout()
plt.show()

# %%
for col in X.columns:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x='NObeyesdad', y=col, data=df)
    plt.title(f"{col} by Level")
    plt.tight_layout()
    plt.show()

# %%
for col in X.columns:
    plt.figure(figsize=(6, 4))
    
    # Barplot of mean of feature grouped by 'Level'
    sns.barplot(x='NObeyesdad', y=col, data=df, estimator='mean', ci=None)
    
    plt.title(f"Average {col} by Level")
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18748\3532519164.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='NObeyesdad', y=col, data=df, estimator='mean', ci=None)
# C:\Users\HP\AppData\Local\Temp\ipykernel_18748\3532519164.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='NObeyesdad', y=col, data=df, estimator='mean', ci=None)
# C:\Users\HP\AppData\Local\Temp\ipykernel_18748\3532519164.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='NObeyesdad', y=col, data=df, estimator='mean', ci=None)
# C:\Users\HP\AppData\Local\Temp\ipykernel_18748\3532519164.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='NObeyesdad', y=col, data=df, estimator='mean', ci=None)
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=42)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
svc = SVC(decision_function_shape='ovr')
svc.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_pred = svc.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
print(accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.8769968051118211
# [[75 10  0  0  0  0  0]
#  [ 4 75 10  4  0  0  0]
#  [ 0 12 68  2  1  0  0]
#  [ 0 12  7 51  2  0  0]
#  [ 0  2  3  1 95  4  1]
#  [ 0  1  0  0  0 99  0]
#  [ 0  0  0  0  0  1 86]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.91        85
#            1       0.67      0.81      0.73        93
#            2       0.77      0.82      0.80        83
#            3       0.88      0.71      0.78        72
#            4       0.97      0.90      0.93       106
#            5       0.95      0.99      0.97       100
#            6       0.99      0.99      0.99        87
#
#     accuracy                           0.88       626
#    macro avg       0.88      0.87      0.87       626
# weighted avg       0.89      0.88      0.88       626

# %%
linear = SVC(kernel='linear')
linear.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred1=linear.predict(X_test)

# %%
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(classification_report(y_test,y_pred1))
# Out:
# 0.9536741214057508
# [[ 85   0   0   0   0   0   0]
#  [ 10  78   5   0   0   0   0]
#  [  0   1  80   2   0   0   0]
#  [  0   0   2  67   3   0   0]
#  [  0   0   0   1 102   3   0]
#  [  0   0   0   0   1  99   0]
#  [  0   0   0   0   0   1  86]]
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94        85
#            1       0.99      0.84      0.91        93
#            2       0.92      0.96      0.94        83
#            3       0.96      0.93      0.94        72
#            4       0.96      0.96      0.96       106
#            5       0.96      0.99      0.98       100
#            6       1.00      0.99      0.99        87
#
#     accuracy                           0.95       626
#    macro avg       0.95      0.95      0.95       626
# weighted avg       0.96      0.95      0.95       626

# %%
new_input = [[1.75, 80, 0, 1, 1,3.22,0.5,2.33,0.454,0.87213,1.0,0.6589,1.0,0.25]] 
new_input_scaled = scaler.transform(new_input)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
X.columns
# Out:
# Index(['Height', 'Weight', 'family_history_with_overweight', 'SCC',
#        'MTRANS_Walking', 'FAVC_z', 'FCVC_minmax', 'NCP_z', 'CAEC_minmax',
#        'CH2O_minmax', 'FAF_minmax', 'TUE_z', 'CALC_z', 'Age_bin_minmax'],
#       dtype='object')

# %%
X
# Out:
#         Height      Weight  family_history_with_overweight  SCC  \
# 0     1.620000   64.000000                               1    0
# 1     1.520000   56.000000                               1    1
# 2     1.800000   77.000000                               1    0
# 3     1.800000   87.000000                               0    0
# 4     1.780000   89.800000                               0    0
# ...        ...         ...                             ...  ...
# 2081  1.710730  131.408528                               1    0
# 2082  1.748584  133.742943                               1    0
# 2083  1.752206  133.689352                               1    0
# 2084  1.739450  133.346641                               1    0
# 2085  1.738836  133.472641                               1    0
#
#       MTRANS_Walking    FAVC_z  FCVC_minmax     NCP_z  CAEC_minmax  \
# 0                  0  2.766876          0.5  0.404704     0.333333
# ...

# %%
prediction = linear.predict(new_input_scaled)
print("Predicted class:", prediction[0])
# Out:
# Predicted class: 2
